# %%
import nltk
import pandas as pd
import sqlite3
import regex as re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#create dataframe from csv
df = pd.read_csv("/Users/abhilashyelahankaramanjaneya/Desktop/Machine_learning_projects/emails.csv", sep=',')
df.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
print("spam count is : " +str(len(df.loc[df["spam"]==1])))
print("Non spam count is: " +str(len(df.loc[df["spam"]==0])))
df['spam'] = df['spam'].astype(int)
print(f"Number of values before removing the duplicates : {len(df.text)}")
df = df.drop_duplicates()
df['text'] = df['text'].str.replace('\d+','')
#     dataf = dataf.reset_index(inplace = False)[['text','spam']]
print(f"Number of values after removing the duplicates : {len(df.text)}")
# Out:
# spam count is : 1368
# Non spam count is: 4360
# Number of values before removing the duplicates : 5728
# Number of values after removing the duplicates : 5695

# %%
df['text'] = df['text'].astype(str)
df = df.applymap(lambda s:s.lower() if type(s) == str else s)
df.head()
# Out:
#                                                 text  spam
# 0  subject: naturally irresistible your corporate...     1
# 1  subject: the stock trading gunslinger  fanny i...     1
# 2  subject: unbelievable new homes made easy  im ...     1
# 3  subject:  color printing special  request addi...     1
# 4  subject: do not have money , get software cds ...     1

# %%
def tokenization(col):
    review = col['text']
    tokens = nltk.word_tokenize(review)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

df['text'] = df.apply(tokenization, axis=1)

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()
def stem_list(col):
    my_list = col['text']
    stemmed_list = [porter.stem(word) for word in my_list]
    return (stemmed_list)

df['text'] = df.apply(stem_list, axis=1)

# %%
def rejoin_words(col):
    my_list = col['text']
    joined_words = ( " ".join(my_list))
    return joined_words

df['text'] = df.apply(rejoin_words, axis=1)
print(df.head())
# Out:
#                                                 text  spam
# 0  subject natur irresist your corpor ident lt is...     1
# 1  subject the stock trade gunsling fanni is merr...     1
# 2  subject unbeliev new home made easi im want to...     1
# 3  subject color print special request addit info...     1
# 4  subject do not have money get softwar cd from ...     1

# %%
stop_words = ['is','you','your','and', 'the', 'to', 'from', 'or', 'I', 'for', 'do', 'get', 'not', 'here', 'in', 'im', 'have', 'on', 're', 'new', 'subject']

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color = 'black', stopwords = stop_words, max_words = 1000
                      , min_font_size = 20).generate(str(df['text']))
#plot the word cloud
fig = plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
data_spam = df.loc[df["spam"]==1]
data_no_spam = df.loc[df["spam"]==0]

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color = 'black', stopwords = stop_words, max_words = 1000
                      , min_font_size = 20).generate(str(data_spam['text']))
#plot the word cloud
fig = plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color = 'black', stopwords = stop_words, max_words = 1000
                      , min_font_size = 20).generate(str(data_no_spam['text']))
#plot the word cloud
fig = plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
