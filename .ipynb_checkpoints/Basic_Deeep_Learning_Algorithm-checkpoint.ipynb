# %%
import pandas as pd
# ^^^ pyforest auto-imports - don't write above this line
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
# load the dataset
dataset = pd.read_csv("/Users/abhilashyelahankaramanjaneya/Desktop/Machine_learning_projects/Projects/Datasets/pima-indians-diabetes.data.csv", sep=',', header=0)
# print(dataset.head())
# split into input (X) and output (y) variables
split = 8
X = dataset.iloc[:,:split]
y = dataset.iloc[:,split]
print(f"Train set is \n {X} ")
print(f"Test set is \n {y} ")
# Out:
# Train set is
#        6  148  72  35    0  33.6  0.627  50
# 0     1   85  66  29    0  26.6  0.351  31
# 1     8  183  64   0    0  23.3  0.672  32
# 2     1   89  66  23   94  28.1  0.167  21
# 3     0  137  40  35  168  43.1  2.288  33
# 4     5  116  74   0    0  25.6  0.201  30
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 762  10  101  76  48  180  32.9  0.171  63
# 763   2  122  70  27    0  36.8  0.340  27
# 764   5  121  72  23  112  26.2  0.245  30
# 765   1  126  60   0    0  30.1  0.349  47
# 766   1   93  70  31    0  30.4  0.315  23
#
# [767 rows x 8 columns]
# Test set is
#  0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 762    0
# 763    0
# 764    0
# 765    1
# 766    0
# Name: 1, Length: 767, dtype: int64

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 0s 905us/step - loss: 10.8947 - accuracy: 0.6206
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 5.2130 - accuracy: 0.5644
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 3.9291 - accuracy: 0.5408
# Epoch 4/150
# 77/77 [==============================] - 0s 938us/step - loss: 2.5178 - accuracy: 0.5508
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.7701 - accuracy: 0.5788
# Epoch 6/150
# 77/77 [==============================] - 0s 863us/step - loss: 1.3197 - accuracy: 0.6254
# Epoch 7/150
# 77/77 [==============================] - 0s 953us/step - loss: 1.1665 - accuracy: 0.5970
# Epoch 8/150
# 77/77 [==============================] - 0s 876us/step - loss: 1.0731 - accuracy: 0.6360
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.0051 - accuracy: 0.6532
# Epoch 10/150
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 828us/step - loss: 0.4964 - accuracy: 0.7614
# Accuracy: 76.14

# %%
# make probability predictions with the model
predictions = model.predict(X)
# round predictions 
rounded = [round(x[0]) for x in predictions]

# %%
# make class predictions with the model
predictions = model.predict_classes(X)
# Out:
# /Users/abhilashyelahankaramanjaneya/Desktop/Machine_learning_projects/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
X_sample = X.iloc[:5,:]
X_sample = X_sample.values.tolist()
print(X_sample[0])
# Out:
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.35100000000000003, 31.0]

# %%
for i in range(5):
    print(f'Sample {i} : %s => %d (expected %d)' % (X_sample[i], predictions[i], y[i]))
# Out:
# Sample 0 : [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.35100000000000003, 31.0] => 0 (expected 0)
# Sample 1 : [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# Sample 2 : [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.16699999999999998, 21.0] => 0 (expected 0)
# Sample 3 : [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.2880000000000003, 33.0] => 1 (expected 1)
# Sample 4 : [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0] => 0 (expected 0)
